# %% [markdown]
# # CST 407 ML - Assignment 1 - part 1
#
# _Code drawn from Chapter 1 – The Machine Learning landscape_
#
# saved as: CST407ML_Assign1_part1_DaveWhite.zip

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# %%
# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
import os
datapath = os.path.join("datasets", "lifesat", "")

# %%
# To plot pretty figures directly within Jupyter
# %matplotlib inline
import matplotlib as mpl
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Download the data
import urllib.request
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
os.makedirs(datapath, exist_ok=True)
for filename in ("oecd_bli_2015.csv", "gdp_per_capita.csv"):
    print("Downloading", filename)
    url = DOWNLOAD_ROOT + "datasets/lifesat/" + filename
    urllib.request.urlretrieve(url, datapath + filename)

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
print(model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# [[5.96242338]]

# %% [markdown]
# # Your turn...
#
# Instructions:
# 1. Look up the GDP for Korea from the Lecture 1 notes
# 2. Predict the Life satisfaction for Korea using the LinearRegression model trained above
# 3. Does this result surprise you?  Write a couple sentences explaining your answer.

# %%
# your code here to make a Life satisfaction prediction for Korea
''' copied from above, and changed the GDP value'''

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Korea
X_new = [[27195]]
print("Life satisfaction prediction is:")
print(model.predict(X_new)) # outputs predicted life satisfaction
# Out:
# Life satisfaction prediction is:
# [[6.18874735]]

# %% [markdown]
# _Your answer to the question:  "Does this result surprise you?"_
#
#     <type your answer here>

# %%
# This resultant value appears to be close to my expectation considering the linear regression model used (no surprise).
# The lecture data shows a life satisfaction value of 5.8 (less than my expectation).

# %%
# I've copied the code once again here to make a Life satisfaction prediction for S. Korea (2021)
# This time I've used a GDP per capita based on a Google search rather than the lecture notes value.

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# The data is already loaded

# The data is already prepared

# Scatter plot data is already calculated

# A linear regression model is already selected

# The model has already been trained.

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')

# Calculate the fitted line
plt.plot(X, model.intercept_ + model.coef_ * X)

# plot the data and the line together
plt.show()

# Make a prediction for S.Korea (2021)
X_new = [[34998]]  # accordcing to a Google search on 1/11/23, South Korea's GDP per capita was $34997.78 USD in 2021
print("Life satisfaction prediction is:")
print(model.predict(X_new)) # outputs predicted life satisfaction
# Out:
# Life satisfaction prediction is:
# [[6.57199518]]

# %%
# This predicted life expectancy value appears correct. (no surprise)
